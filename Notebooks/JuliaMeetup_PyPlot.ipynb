# %% [markdown]
# # PyPlot.jl
#
# ### A plotting package for people who miss matplotlib
#
# **Author**: Chase Coleman
#
# **Date**: 31 March 2016

# %%
using PyPlot

# %% [markdown]
# ## Simple Examples
#
# Here we avoid all extraneous features and just show some of the basic plot types that can be created with PyPlot.jl

# %%
npts = 125

d = randn(npts)
x = linspace(0, 2*π, npts)
y = copy(x)
sinx = sin(x)
cosx = cos(x)
z = cos(x') .+ sin(y);

# %% [markdown]
# ### Line Plot

# %%
plot(x, sinx)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0270f1bbd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f0270f008d0>

# %% [markdown]
# ### Scatter Plot

# %%
scatter(x, d)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0270c20250>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f0270c9ddd0>
# /home/chase/.julia/v0.4/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ### Histogram

# %%
plt[:hist](d);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0270c137d0>)

# %% [markdown]
# Why do we need the `plt[:hist]`? Reading the docs will warn you that:
#
# > You must also use `plt` to access some functions that conflict with built-in Julia functions. In particular `plt[:hist]`, `plt[:xcorr]`, and `plt[:isinteractive]` must be used to access `matplotlib.pyplot.hist etcetera`.

# %% [markdown]
# ### Heatmap

# %%
pcolormesh(x, y, z)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0270eaaed0>)
# PyObject <matplotlib.collections.QuadMesh object at 0x7f026de5f750>

# %% [markdown]
# ### Surface Maps
#
# `PyPlot.jl` makes our life easier than in `matplotlib` because we aren't required to create a `Axes3D` object before making a 3-D plot

# %%
surf(x', y, z)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0270c68f10>)
# PyObject <mpl_toolkits.mplot3d.art3d.Poly3DCollection object at 0x7f026de52750>

# %% [markdown]
# ## More Features
#
# Build up 4 plots using different features

# %%
fig, ax = subplots(2, 2)

ax1, ax2, ax3, ax4 = ax
tight_layout()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f026de5a090>)

# %% [markdown]
# ### Visualization Features

# %%
ax1[:plot](x, sinx, color="k", linewidth=5.0, linestyle="-", alpha=0.3)
ax1[:scatter](x[1:5:end], sinx[1:5:end], color=["red", "green", "blue"],
              s=100*abs(sinx[1:5:end]))
ax3[:hist](d, color="#009900")
fig
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f026de5a090>)

# %%
get_cmaps()[1:5:end]
# Out:
# 15-element Array{PyPlot.ColorMap,1}:
#  ColorMap "Accent"
#  ColorMap "bone"
#  ColorMap "bwr"
#  ColorMap "cubehelix"
#  ColorMap "gist_heat"
#  ColorMap "GnBu"
#  ColorMap "Greys"
#  ColorMap "ocean"
#  ColorMap "Pastel2"
#  ColorMap "PuBu"
#  ColorMap "rainbow"
#  ColorMap "RdYlGn"
#  ColorMap "Set3"
#  ColorMap "terrain"
#  ColorMap "YlOrBr"

# %%
ax2[:pcolormesh](z, cmap="bwr")
ax4[:barh](x[1:5:end], cosx[1:5:end], color=["red", "blue", "green"])
fig
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f026de5a090>)

# %% [markdown]
# ### Titles and Axis Labels

# %%
ax1[:set_title]("Sin plot with colored dots")
ax3[:set_title]("Green Histogram")
ax1[:set_ylabel]("sin(x)")
ax3[:set_ylabel]("Density")
fig
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f026de5a090>)

# %% [markdown]
# ### Change Axis Limits

# %%
ax1[:set_xlim](0, 2*π)
ax2[:set_xlim](1, npts)
ax2[:set_ylim](1, npts)
fig
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f026de5a090>)

# %% [markdown]
# ### Annotation

# %%
littleindex = div(npts, 2)
xlittle, sinlittle = x[littleindex-1], sinx[littleindex-1]
ax1[:annotate](L"$\min_x sin(x)$", xy=(xlittle, sinlittle),
               xytext=(xlittle+1, sinlittle+0.5),
               arrowprops=Dict(:facecolor=>"black", :shrink=>0.1))
fig
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f026de5a090>)

# %% [markdown]
# ### Facecolors and backgrounds

# %%
ax1[:set_axis_bgcolor]("#ccccff")
ax3[:set_axis_bgcolor]("magenta")
ax4[:set_axis_bgcolor]((255/256, 255/256, 153/256))
fig[:set_facecolor]("blue")
fig
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f026de5a090>)

# %% [markdown]
# ## Plots.jl
#
# Unified interface to various plotting packages
#
# Add `Plots.` in front of all commands because it conflicts with previous namespace from `PyPlot`. Wouldn't normally need that prefix.

# %%
using Plots
pyplot()
# Out:
# WARNING: using Plots.scatter in module Main conflicts with an existing identifier.
# WARNING: using Plots.plot in module Main conflicts with an existing identifier.

# %%
Plots.plot(x, sinx, leg=false, color=:red, style=:dash)
# Out:
# [Plots.jl] Initializing backend: pyplot
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M35.0075 263.298
# L417.165 263.298
# L417.165 16.8312
# L35.0075 16.8312
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p494053b5d5)" d="
# M35.0075 263.298
# ...

# %%
Plots.contour(x, y, z, fill=true)
Plots.scatter!([2.5], [2.5], color=:black, ms=3, leg=false)
Plots.annotate!([(2.5, 2.5, Plots.text("This is 2.5, 2.5", 12, :white, :left))])
# Out:
# /home/chase/.julia/v0.4/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M21.21 263.298
# L339.474 263.298
# ...

# %%
Plots.heatmap(randn(10000), randn(10000), nbins=25)
Plots.title!("Heatmap")
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M27.265 263.298
# L340.685 263.298
# L340.685 26.3183
# L27.265 26.3183
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pacd17f8142)" d="
# M57.9352 263.298
# ...

# %%
Plots.subplot(randn(100, 4), layout=[2, 2], t=[:line :hist :scatter :bar],
              nbins=25, leg=false, color=[:red :blue :green :black])
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M27.265 125.777
# L198.719 125.777
# L198.719 16.8313
# L27.265 16.8313
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pb15aab49b8)" d="
# M27.265 125.777
# ...
